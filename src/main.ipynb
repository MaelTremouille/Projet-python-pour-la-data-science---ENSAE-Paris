# %% [markdown]
# # **Présentation Générale du Projet**
#
# Dans un contexte où l’information alimentaire est devenue centrale pour les consommateurs, comprendre la composition et la qualité nutritionnelle des produits que nous consommons est un enjeu majeur. Au-delà de la simple liste d’ingrédients, le public s’intéresse aujourd’hui aux nutriments, aux labels de qualité, à l’impact environnemental, ou encore aux classements de type Nutriscore. C’est dans cette optique que s’inscrit ce projet, qui s’appuie sur la base de données collaborative *Open Food Facts*. Cette dernière met à disposition des informations nutritionnelles et environnementales sur des milliers de produits alimentaires, provenant de pays et de marques variés.

# %% [markdown]
# ### **Problématique générale :**
#
#
# De manière large, notre but est d’explorer l’univers des produits alimentaires tels qu’ils sont référencés par *Open Food Facts*, afin d’en apprendre davantage sur la qualité de notre alimentation. Comment se répartissent les nutriments d’un produit à l’autre ? Quels sont les liens entre les profils nutritionnels, le type de produit, et des indicateurs comme le Nutriscore, le Novascore ou l’Ecoscore ? Peut-on, sur la base de ces informations, anticiper ou prédire le Nutriscore d’un produit avant même de l’avoir officiellement calculé ?

# %% [markdown]
# ## **0- Initialisation**

# %% [markdown]
# On doit d'abord s'assurer d'être au bon endroit et d'avoir le bon *working directory*, à savoir : *Projet-python-pour-la-data-science---ENSAE-Paris*.

# %%
import os

def set_working_directory(target_dir_name):
    current_dir = os.getcwd()
    
    while os.path.basename(current_dir) != target_dir_name:
        parent_dir = os.path.dirname(current_dir)
        if current_dir == parent_dir:  
            raise FileNotFoundError(f"Le dossier cible '{target_dir_name}' n'a pas été trouvé dans l'arborescence.")
        current_dir = parent_dir

    os.chdir(current_dir)
    print(f"Le working directory est maintenant :\n {os.getcwd()}")


try:
    set_working_directory("Projet-python-pour-la-data-science---ENSAE-Paris")
except FileNotFoundError as e:
    print(e)
# Out:
# Le working directory est maintenant :
#  c:\Users\trema\OneDrive\Bureau\ENSAE Paris\Cours\S1\4. Python pour la data science\Projet-python-pour-la-data-science---ENSAE-Paris

# %% [markdown]
# ## **1- La création et le traitement de la base de données**

# %% [markdown]
# Dans un premier temps, nous veillons à créer et à alimenter une base de données cohérente, extraite et nettoyée à partir des informations disponibles dans *Open Food Facts*. Un script d’initialisation permet d’instancier une base à partir d’une liste de codes-barres, enrichis au besoin par des requêtes API. Au-delà de la simple récupération des données, cette phase comprend le nettoyage, la vérification des types de variables, le traitement des valeurs manquantes, ainsi que la création de nouvelles catégories (par exemple Categorie_clean) regroupant les produits selon leurs similarités.

# %% [markdown]
# On se sert directement du fichier *src/services/init/initialisation.json*. Ce fichier contient une liste de codes-barres que l'on utilise pour instancier la base de données *src/database/barcodes.json*.

# %% [markdown]
# Le répertoire de travail a été correctement défini. Cela garantit que tous les chemins relatifs pour l’importation de modules, le chargement de données et l’enregistrement des résultats pointeront vers les bons fichiers du projet. Cela permet d’éviter les erreurs de chargement de données.

# %% [markdown]
# On importe ensuite la class **Barcodes** afin de récupérer la BDD sous forme de *DataFrame*. Si celle-ci n'existe pas déjà, elle est initialisée avec des barcodes stockés dans *'src/service/init/initialisation.json'*.

# %%
from src.services.barcodes import Barcodes
bar = Barcodes()
print(bar.df.columns)
# Out:
# Fichier .env chargé avec succès.
# Index(['Nom', 'Categorie', 'Nutriscore', 'Novascore', 'Ecoscore',
#        'Taux de sel (100g)', 'Taux de matieres grasses (100g)',
#        'Taux de matieres grasses saturees (100g)', 'Taux de proteine (100g)',
#        'Taux de sucre (100g)', 'Energie (Kcal) (100g)'],
#       dtype='object')

# %% [markdown]
# N.B. S'il y a une erreur dans le code précédent :
# *pip install python-dotenv*

# %% [markdown]
# Les colonnes extraites de la base de données indiquent les variables disponibles pour chaque produit. Nous disposons d’informations nutritionnelles (sel, matières grasses, protéines, sucre, énergie), d’indicateurs de qualité (Nutriscore, Novascore, Ecoscore) et de métadonnées (Nom, Catégorie). Ces informations sont essentielles pour analyser la qualité nutritionnelle des produits, repérer des corrélations et effectuer par la suite des modèles prédictifs

# %% [markdown]
# Une fois que cela a été fait, on peut désormais créer une nouvelle catégorie, appelée **catégorie_clean**, celle-ci permet de regrouper différents produits qui ont des caractéristiques communes (les categories directement extraites avec l'API sont parfois très spécifiques et ne reflète pas la catégorie mais plutot le nom du produit: cela est du au fait que *Open Food Fact* et un outil collaboratif ou les gens renseignent eux mêmes les informations   ). Ensuite, on peut afficher un aperçu de la base de données (BDD). On fait cela via la classe **Processing** qui hérite de la classe **Barcodes**.

# %%
from src.services.processing import Processing
processing = Processing()

# On récupère de DataFrame
data = processing.df

# Affichage des données transformées
print(f"Nom des colonnes :\n{[name for name in data.columns]}")
print('-'*60 + '\n')
print("Les 10 premières lignes de la BDD :")
data.head(10)
# Out:
# Nom des colonnes :
# ['Nom', 'Nutriscore', 'Ecoscore', 'Taux de sel (100g)', 'Taux de matieres grasses (100g)', 'Taux de matieres grasses saturees (100g)', 'Taux de proteine (100g)', 'Taux de sucre (100g)', 'Energie (Kcal) (100g)', 'Categorie_clean']
# ------------------------------------------------------------
#
# Les 10 premières lignes de la BDD :
#                                                Nom Nutriscore  Ecoscore  \
# Barcode
# 3073781055016                    Fagotin tradition          d      47.0
# 3564707128117              Ricotta bio 8% Mat. Gr.          c      60.0
# 3564700583135   Fromage Le Carre Au Lait Pasterise          d      44.0
# 3596710495979                    Gouda tranchettes          d      38.0
# 3564707090162                       Mozzarella x 1          c      65.0
# 3330410005980                   Edam tranches 200g          d      35.0
# 5010578008044        Cottage Cheese With Pineapple          c      35.0
# 3250391819256  Le Sainte-Maure - Fromage de chèvre          d      22.0
# 3257986760191             Mozarella cossettes cora          d      40.0
# 3222472116851              La Raclette en tranches          d      45.0
#
#                Taux de sel (100g)  Taux de matieres grasses (100g)  \
# Barcode
# 3073781055016              1.4000                             28.0
# 3564707128117              0.4000                              8.0
# 3564700583135              1.6000                             27.0
# 3596710495979              1.7000                             28.0
# 3564707090162              0.6000                             19.0
# 3330410005980              2.1000                             24.0
# 5010578008044              0.7000                              5.6
# 3250391819256              1.3775                             19.0
# 3257986760191              1.1000                             22.0
# 3222472116851              1.7000                             26.0
#
#                Taux de matieres grasses saturees (100g)  \
# Barcode
# 3073781055016                                      19.0
# 3564707128117                                       6.0
# 3564700583135                                      19.0
# 3596710495979                                      19.0
# 3564707090162                                      13.0
# 3330410005980                                      16.0
# 5010578008044                                       3.9
# 3250391819256                                      13.0
# 3257986760191                                      15.0
# 3222472116851                                      18.0
#
#                Taux de proteine (100g)  Taux de sucre (100g)  \
# Barcode
# 3073781055016                     20.0                   0.5
# 3564707128117                      8.0                   3.0
# 3564700583135                     18.0                   0.5
# 3596710495979                     24.0                   0.5
# 3564707090162                     18.0                   1.0
# 3330410005980                     25.0                   0.5
# 5010578008044                      9.5                   5.1
# 3250391819256                     19.0                   0.8
# 3257986760191                     26.0                   0.6
# 3222472116851                     23.0                   0.0
#
#                Energie (Kcal) (100g)    Categorie_clean
# Barcode
# 3073781055016                  332.0  Produits laitiers
# 3564707128117                    NaN  Produits laitiers
# 3564700583135                  319.0  Produits laitiers
# 3596710495979                  350.0  Produits laitiers
# 3564707090162                  247.0  Produits laitiers
# 3330410005980                  316.0  Produits laitiers
# 5010578008044                  109.0  Produits laitiers
# 3250391819256                  256.0  Produits laitiers
# 3257986760191                  312.0  Produits laitiers
# 3222472116851                  328.0  Produits laitiers

# %% [markdown]
#  Le nouveau DataFrame inclut désormais la colonne Categorie_clean qui regroupe les produits selon des critères de similarité alimentaire. L’aperçu des deux premières lignes montre notamment les variables nutritionnelles clés. On observe par exemple un premier produit avec un Nutriscore ‘d’, un Ecoscore de 47, et une teneur élevée en matières grasses, tandis que le second produit a un Nutriscore ‘c’ et un Ecoscore de 60. L’absence de valeur (NaN) pour l’énergie dans le second produit signale la présence de données manquantes qu’il faudra potentiellement traiter par la suite.

# %% [markdown]
# On peut également vérifier que les variables sont du bon type (la classe **Processing** permet de mettre toutes les variables au bon type).

# %%
print(data.dtypes)
# Out:
# Nom                                          object
# Nutriscore                                   object
# Ecoscore                                    float64
# Taux de sel (100g)                          float64
# Taux de matieres grasses (100g)             float64
# Taux de matieres grasses saturees (100g)    float64
# Taux de proteine (100g)                     float64
# Taux de sucre (100g)                        float64
# Energie (Kcal) (100g)                       float64
# Categorie_clean                              object
# dtype: object

# %% [markdown]
# Les variables nutritionnelles et l’Ecoscore sont correctement typées en float, permettant des opérations statistiques et des analyses quantitatives. Les variables ‘Nom’, ‘Nutriscore’ et ‘Categorie_clean’ sont de type objet, convenant à l’analyse qualitative (par exemple, classification de produits, comptage par catégorie). Aucune anomalie notable au niveau des types n’est détectée.

# %% [markdown]
# ## **2- Statistiques sur la BDD**

# %% [markdown]
# Une fois la base de données prête, un travail d’exploration est entrepris. Cette étape consiste à analyser la distribution des variables : teneur en sel, taux de sucre, matières grasses, protéines, énergie, etc. On étudie également la répartition des produits par catégories, leur Nutriscore, ainsi que l’Ecoscore, afin de saisir la diversité des profils produits. Le calcul de statistiques descriptives univariées (moyennes, médianes, quartiles) et multivariées (corrélations, covariances) permet d’obtenir une vue d’ensemble du dataset.
# Des visualisations (histogrammes, boxplots, heatmaps) sont proposées pour donner un aperçu plus intuitif des distributions et des relations entre variables. Par exemple, une matrice de corrélation permet d’identifier quels nutriments sont fortement liés entre eux. On peut observer si les produits caloriques sont aussi ceux les plus gras, si le sel est corrélé à la protéine, ou encore si l’Ecoscore entretient des liens marqués avec certains nutriments.

# %% [markdown]
# Commençons par importer la classe **Statistiques** qui nous permettra de réaliser toutes les statistiques :

# %%
from src.services.stats import Statistiques
stats = Statistiques()
data = Statistiques().df

# %% [markdown]
# ### **a) Données manquantes**

# %%
na_par_variable = data.apply(lambda x: x.isna().sum()).sort_values(ascending=False)
print(na_par_variable)
print('-'*60)
print(f"Nombre total d'obsevations {len(data)}")
# Out:
# Ecoscore                                    90
# Taux de sel (100g)                          50
# Energie (Kcal) (100g)                       44
# Taux de matieres grasses saturees (100g)    38
# Taux de sucre (100g)                        36
# Taux de matieres grasses (100g)             34
# Taux de proteine (100g)                     32
# Categorie_clean                              5
# Nom                                          4
# Nutriscore                                   0
# dtype: int64
# ------------------------------------------------------------
# Nombre total d'obsevations 496

# %% [markdown]
# On constate que certaines variables, comme l’Ecoscore, présentent un nombre important de valeurs manquantes (78 sur 482 observations), Le nombre élevé de valeurs manquantes pour l’Écoscore témoigne d’une indisponibilité ou d’une non-collecte de ces données, ce qui réduit leur représentativité et complique l’interprétation ; c’est dans ce cadre que l’affichage Éco-score deviendra à terme obligatoire : initialement prévu pour le 1er janvier 2024, il est actuellement repoussé pour être amélioré, sans communication sur une date d’application ultérieure.

# %% [markdown]
# ### **b) Statistiques descriptives univariées**

# %% [markdown]
# On peut commencer par s'intéresser aux moyennes et aux écarts-types de chaque colonne si elles sont numériques ou alors à leur histogramme sinon.

# %%
data.describe()
# Out:
#          Ecoscore  Taux de sel (100g)  Taux de matieres grasses (100g)  \
# count  406.000000          446.000000                       462.000000
# mean    52.241379            0.775744                        18.091205
# std     27.295111            1.458510                        23.266204
# min    -20.000000            0.000000                         0.000000
# 25%     31.000000            0.030153                         1.700000
# 50%     52.000000            0.350000                        11.000000
# 75%     74.000000            1.081875                        23.000000
# max    114.000000           17.100000                       100.000000
#
#        Taux de matieres grasses saturees (100g)  Taux de proteine (100g)  \
# count                                458.000000               464.000000
# mean                                   5.522736                 7.334361
# std                                    7.782710                 7.095956
# min                                    0.000000                 0.000000
# 25%                                    0.500000                 1.200000
# 50%                                    2.800000                 6.000000
# 75%                                    7.350000                10.850000
# max                                   84.000000                39.200000
#
#        Taux de sucre (100g)  Energie (Kcal) (100g)
# count            460.000000             452.000000
# mean              15.882406             326.123516
# std               20.392670             211.889985
# min                0.000000               0.000000
# 25%                0.800000             154.750000
# 50%                4.600000             322.500000
# 75%               30.250000             436.000000
# max              100.000000             900.000000

# %% [markdown]
# Les statistiques descriptives révèlent la répartition des valeurs pour chaque variable numérique. Par exemple, l’Ecoscore moyen est d’environ 52, ce qui suggère un niveau moyen de performance écologique. La teneur en sel varie grandement avec une moyenne autour de 0,8g / 100g, mais pouvant aller jusqu’à plus de 17g / 100g (valeur sans doute extrême ou rare). Le sucre et l’énergie présentent également une large dispersion (écart-type élevé), indiquant une grande hétérogénéité dans les produits.

# %% [markdown]
# On peut ensuite regarder la moyenne dans chaque groupe de '*Categorie_clean*'.

# %%
stats.mean_by_category('Taux de matieres grasses (100g)')

# %% [markdown]
# **Interprétation :**
#
#  Le diagramme met en évidence d’importants écarts dans la teneur moyenne en matières grasses selon les différentes catégories de produits. Logiquement, la catégorie **“Huiles et graisses”** arrive largement en tête, puisqu’il s’agit avant tout de produits pratiquement constitués de lipides (huiles de cuisson, margarine, beurre, etc.). Viennent ensuite **“Sauces et épices”**, dont certaines préparations incluent une proportion élevée d’huile ou de crème, ainsi que les **“Produits laitiers”** (fromages, crème fraîche…), traditionnellement riches en graisses.
#
#  À l’autre extrémité, les **“Boissons”**, les **“Légumes et féculents”** ou encore les **“Produits céréaliers”** affichent un taux de matières grasses moyen très faible, ce qui correspond à la nature même de ces produits (eau, fibres, amidon…). Cette diversité reflète l’hétérogénéité de l’offre alimentaire : certaines catégories sont presque exclusivement composées de lipides, alors que d’autres reposent davantage sur des glucides ou de l’eau. Au final, ce classement des catégories par teneur moyenne en matières grasses se révèle cohérent avec nos connaissances en nutrition et confirme que le choix de la catégorie d’un produit influe fortement sur son profil lipidique.

# %%
stats.boxplot_categorie("Energie (Kcal) (100g)")
# Out:
# c:\Users\trema\OneDrive\Bureau\ENSAE Paris\Cours\S1\4. Python pour la data science\Projet-python-pour-la-data-science---ENSAE-Paris\src\services\stats.py:126: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x=filtered_df['Categorie_clean'], y=filtered_df[variable], palette="Set3")

# %% [markdown]
# Cela explique le fait qu'il y ait des boxplots plats. On peut donc réappliquer la méthode avec cette fois-ci l'atribut *'few_obs'* qui nous permet de rentrer le nombre minimal d'observations à avoir dans une catégorie pour réaliser le boxplot.

# %% [markdown]
# On ne va garder que les catégories qui contiennent au moins 5 observations.

# %%
stats.boxplot_categorie("Energie (Kcal) (100g)", 5)
# Out:
# c:\Users\trema\OneDrive\Bureau\ENSAE Paris\Cours\S1\4. Python pour la data science\Projet-python-pour-la-data-science---ENSAE-Paris\src\services\stats.py:126: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x=filtered_df['Categorie_clean'], y=filtered_df[variable], palette="Set3")

# %% [markdown]
# Qu'en est-il pour les données catégorielles ?

# %%
import matplotlib.pyplot as plt
# Compter les occurrences de chaque catégorie
counts_nutriscore = data['Nutriscore'].value_counts()


# Créer un graphique en barres
plt.figure(figsize=(8, 5))
counts_nutriscore.plot(kind='bar', color='skyblue')
plt.title('Distribution des scores dans Nutriscore')
plt.xlabel('Nutriscore')
plt.ylabel('Fréquence')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# **Interprétation :**
#
# Le diagramme met en évidence que la catégorie la plus représentée est “d”, suivie de “c”, puis de “a” et “e”. Cela indique qu’une proportion importante de produits se situe dans des classes Nutriscore considérées comme moyennes à défavorables sur le plan nutritionnel.
#
# On note également la présence de labels “unknown” et “not-applicable”, qui correspondent soit à des produits pour lesquels le calcul Nutriscore n’a pas pu être effectué, soit à des cas où cet indicateur n’est pas pertinent.
#
# La relative rareté du Nutriscore “b” pourrait signaler une moindre représentation de produits intermédiaires entre les catégories très saines (“a”) et moyennes/défavorables (“c” et “d”).
#
# Globalement, cette répartition suggère un certain déséquilibre : la majorité des produits de l’échantillon ne sont pas en haut de l’échelle de qualité nutritionnelle. Cet élément est à garder en tête lors de l’analyse, car il peut influencer les moyennes nutritionnelles ou biaiser la perception de la globalité de l’offre.

# %%
# Compter les occurrences de chaque catégorie
counts_Categorie_clean = data['Categorie_clean'].value_counts()

# Créer un graphique en barres
plt.figure(figsize=(8, 5))
counts_Categorie_clean.plot(kind='bar', color='skyblue')
plt.title('Distribution des produits par Categorie_clean')
plt.xlabel('Catégories')
plt.ylabel('Fréquence')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Interprétation :**
#
# Les “Aliments végétaux” constituent la catégorie la plus fréquente, ce qui peut refléter l’importance donnée à des produits d’origine végétale (fruits, légumes, légumineuses) dans la base.
#
# Les “Snacks et sucreries” et “Viandes et produits carnés” arrivent ensuite, indiquant qu’une part non négligeable de l’offre se compose de produits transformés sucrés ou carnés, généralement moins bien notés du point de vue nutritionnel.
#
# On observe une distribution inégale, avec d’autres catégories nettement moins représentées telles que les “Boissons” ou les “Huiles et graisses”.
#
# **Impact sur le Nutriscore** : la forte présence des catégories “Snacks et sucreries” et “Viandes et produits carnés” peut partiellement expliquer la répartition observée dans le diagramme du Nutriscore (beaucoup de “d”). Les produits de ces catégories ont souvent un profil nutritionnel moins favorable (taux élevés de sel, de sucres ou de graisses saturées), ce qui tire la note vers le bas. Cela illustre que la nature même des produits disponibles dans la base de données influence grandement la répartition globale des Nutriscores.

# %% [markdown]
# ### **c) Statistiques descriptives multivariées**

# %% [markdown]
# On souhaite désormais s'intéresser à la covariance entre les variables deux à deux. On peut pour ce faire regarder la matrice des covariances.

# %%
stats.corr_matrix()

# %% [markdown]
# **Taux de matières grasses et Energie (Kcal) :**
#
# La corrélation entre le « Taux de matières grasses (100g) » et l’« Energie (Kcal) (100g) » est très élevée et positive (valeur ~0.85). Cela signifie que plus un produit est gras, plus il a tendance à être calorique. Cette relation est cohérente d’un point de vue nutritionnel, les lipides étant la source la plus concentrée en calories.
#
# **Taux de matières grasses saturées et Energie (Kcal) :**
#
# Le « Taux de matières grasses saturées (100g) » est également positivement corrélé avec l’énergie (~0.54). C’est une relation moins forte que le taux global de matières grasses, mais montre tout de même qu’un produit riche en graisses saturées est généralement plus calorique.
#
# **Taux de sucre (100g) :**
#
# Le « Taux de sucre (100g) » a une corrélation négative avec le « Taux de proteine (100g) » et une faible corrélation avec la plupart des autres variables. Cela indique que les produits très sucrés ne sont pas nécessairement ceux les plus gras, salés ou protéinés. Le sucre semble être relativement indépendant des autres macronutriments, ce qui reflète la diversité des produits sucrés (fruits, confiseries, boissons) qui n’ont pas tous les mêmes profils nutritionnels.
#
# **Ecoscore :**
#
# L’« Ecoscore » présente des corrélations relativement faibles avec les autres variables (autour de -0.14 à -0.36). La corrélation négative la plus marquée est entre l’Ecoscore et le « Taux de proteine (100g) » (~-0.36). Cela pourrait suggérer que les produits plus riches en protéines ne sont pas forcément les plus vertueux sur le plan environnemental, ou inversement, que les produits avec un meilleur Ecoscore sont souvent moins riches en protéines. Cette relation reste toutefois modérée et n’est pas suffisante pour établir une causalité. De manière générale, l’Ecoscore dépend de critères plus complexes (emballage, origine, production), moins directement liés aux seuls macronutriments.
#
# **Taux de sel (100g) :**
#
# Le « Taux de sel (100g) » est positivement corrélé au taux de protéine et faiblement négativement corrélé à l’Ecoscore. Les produits plus salés sont souvent transformés ou issus de filières moins durables, ce qui pourrait expliquer cette légère corrélation négative avec l’Ecoscore, même si elle reste faible.
#
# **En résumé**, les relations les plus notables se trouvent entre les matières grasses (y compris saturées) et l’énergie, ce qui est cohérent avec la densité calorique des lipides. L’Ecoscore ne présente pas de fortes corrélations directes avec ces variables nutritionnelles, suggérant que la performance environnementale d’un produit n’est pas simplement liée à sa composition nutritionnelle. Les autres relations sont plus nuancées et montrent une certaine indépendance entre sucre, protéines, sel et Ecoscore, indiquant que les produits alimentaires couvrent une large diversité de profils nutritionnels et environnementaux.

# %% [markdown]
# ## **3- Mise à jour BDD**

# %% [markdown]
# Maintenant que nous avons donné quelques statistiques sur la BDD qui nous permettent de mieux comprendre la répartition des variables, nous souhaitions tout de même inclure l'option de mettre à jour la BDD. En effet, nous pouvons chercher un code barre dans la base de données, si celui-ci n'est pas déjà présent, alors nous faisons une requête API pour l'ajouter à la BDD.

# %% [markdown]
# On se sert ici de la classe **Barcodes** pour interagir avec la BDD.

# %% [markdown]
# ### a) Navigation dans la BDD

# %% [markdown]
# Commençons par rechercher un barcode qui appartient déjà à la BDD. On n'a ainsi pas besoin de requêter l'API car on peut directement requêter la BDD.

# %%
bar = Barcodes()
data = bar.df
barcode = '3229820789118'
print(bar.get_product(barcode))
# Out:
# L'url associée au barcode est : https://world.openfoodfacts.org/api/v0/product/3229820789118.json
# Ce produit associé au code barre 3229820789118                   vient d'être ajouté à la BDD
# Nom                                                                      Lunettes fraise
# Categorie                                                        fr:lunettes-a-la-fraise
# Nutriscore                                                                             d
# Novascore                                   en:4-ultra-processed-food-and-drink-products
# Ecoscore                                                                             N/A
# Taux de sel (100g)                                                                   0.1
# Taux de matieres grasses (100g)                                                     15.0
# Taux de matieres grasses saturees (100g)                                             4.6
# Taux de proteine (100g)                                                              6.0
# Taux de sucre (100g)                                                                33.0
# Energie (Kcal) (100g)                                                              436.0
# Name: 3229820789118, dtype: object

# %% [markdown]
# Le produit correspondant au code-barres spécifié a été trouvé dans la BDD. Si c’était la première fois qu’on recherchait ce code-barres, le produit a été ajouté après requête à l’API Open Food Facts, enrichissant ainsi la base de données. On observe le nom du produit (‘Lunettes fraise’), sa catégorie spécifique, son Nutriscore (‘d’), et des informations nutritionnelles. Cela confirme la flexibilité et la mise à jour dynamique de notre base.

# %% [markdown]
# ### **b) Suppression de données**

# %% [markdown]
# Supprimons le code-barre que l'on vient de chercher.

# %%
print(f"Nombre d'observation avant la suppression : {len(data)}")
bar.delete_product(barcode)
print(f"Nombre d'observation après la suppression : {len(data)}")
# Out:
# Nombre d'observation avant la suppression : 497
# Suppression de 3229820789118 confirmée.
# Nombre d'observation après la suppression : 496

# %% [markdown]
# Après suppression, une observation a disparu du dataset, ce qui illustre la capacité de modifier dynamiquement la base de données. Ce nettoyage sélectif peut être utile si certains produits sont mal renseignés, obsolètes ou non pertinents pour une analyse.

# %% [markdown]
# ### **c) Ajout de nouvelles données**

# %% [markdown]
# Ré-ajoutons maintenant la donnée que l'on vient de supprimer.

# %%
print(f"Nombre d'observation avant l'ajout : {len(data)}")
bar.get_product(barcode)
print(f"Nombre d'observation après l'ajout : {len(data)}")
# Out:
# Nombre d'observation avant l'ajout : 498
# Nombre d'observation après l'ajout : 498

# %% [markdown]
# Le ré-ajout du même code-barres montre la souplesse du système à interagir avec l’API et la BDD. Cela permet de maintenir la base à jour, d’ajouter de nouveaux produits ou de restaurer ceux supprimés, garantissant un dataset évolutif et adapté aux besoins de l’analyse.

# %% [markdown]
# ### **d) suppression de la BDD**

# %% [markdown]
# Le code suivant est commenté pour éviter que vous supprimiez la base de données en faisant tourner le code. Vous pouvez le décommenter pour vérifier que cela supprimer bien la base de données. Le code ci-dessous est par défaut commenté pour éviter d'avoir à ré-importer la BDD à chaque fois.

# %%
# bar.clear_database()
# print(bar.df)
# print(bar.df.empty)

# %% [markdown]
# ## **4- Modèle prédictifs**

# %% [markdown]
# Après avoir bien cerné la nature des données, leur qualité et leurs limites, une étape importante consiste à envisager des méthodes prédictives. L’objectif principal que nous nous fixons est de tenter de prédire le Nutriscore d’un produit à partir de ses caractéristiques nutritionnelles. Le Nutriscore, indicateur devenu populaire pour guider le consommateur dans ses choix, résulte souvent d’une formule complexe prenant en compte le taux de sucre, de sel, de protéines, de fibres, de graisses saturées, etc.
# Grâce aux informations disponibles (variables nutritionnelles, catégories, etc.), nous allons chercher à construire un modèle de classification supervisée.

# %% [markdown]
# On va utiliser par la suite les classes **LogisticRegressionPrediction** et **RandomForestPrediction** qui hériterons toutes deux de la ***classe abstraite*** **AbstractModelPrediction**. Cette dernière permet de créer les *DataFrames* adaptés, de définir les méthodes d'évaluation des modèles et de fixer les méthodes que devront définir les classes filles. Les classes filles permettront l'entraînement des modèles et permettront également de récupérer les détails spécifiques à chaque modèle.

# %% [markdown]
# ### **a) Description de la variable cible**

# %% [markdown]
# Avant tout, regardons la répartition de la varible d'intérêt ici : **le Nutriscore**.

# %% [markdown]
# On va regarder les différentes valeurs qui peuvent être prises par cette variable et effectuer les modifications nécessaires pour avoir une modèle cohérent. Rappelons que l'on n'a ici **aucune** valeur manquante (c.f. étude préliminaire).

# %%
bar = Barcodes()
data = bar.df
counts_all = data['Nutriscore'].value_counts()
print("Répartition des produits par Nutriscore (tous labels) :")
print(counts_all)
# Out:
# Répartition des produits par Nutriscore (tous labels) :
# Nutriscore
# d                 156
# c                  96
# a                  67
# e                  61
# unknown            59
# b                  50
# not-applicable      8
# Name: count, dtype: int64

# %% [markdown]
# On remarque qu'il y a **59** *unknown* et **8** *not-applicable*. Nous n'allons pas considérer dans nos modèles ces observations car cela ne nous semble pas pertinent de prédire ces valeurs.

# %% [markdown]
# Ce déséquilibre dans la répartition (peu de “b”, beaucoup de “d”) peut influer sur les analyses statistiques ou les modèles prédictifs : les algorithmes risquent, par exemple, de mieux reconnaître la classe majoritaire “d” que d’autres classes moins présentes.

# %% [markdown]
# ### **b) Modèle 1 : régression logistique**

# %%
import warnings
from pandas.errors import SettingWithCopyWarning

warnings.filterwarnings("ignore", category=SettingWithCopyWarning)

# %% [markdown]
# Pour faire suite à ce qui a été dit précédemment, on vérifie que dans la variable cible nous n'avons plus d'éléments *unknown* et *not-applicable*.

# %%
from src.services.prediction_rl import LogisticRegressionPrediction
pred = LogisticRegressionPrediction()
counts_filtered = pred.y.value_counts()
print("\nRépartition des produits par Nutriscore (a, b, c, d, e seulement) :")
for idx in counts_filtered.index:
    print(pred.encoding_dict[idx], counts_filtered[idx])
# Out:
# Répartition des produits par Nutriscore (a, b, c, d, e seulement) :
# d 156
# c 96
# a 67
# e 61
# b 50

# %% [markdown]
# On peut faire une régression logistique car nous cherchons à prédire une variable catégorielle. Commençons par rappeler les variables dont nous disposons :

# %% [markdown]
# On crée une instance et on applique le modèle de **régression logistique**.

# %%
from src.services.processing import Processing
from src.services.prediction_rl import LogisticRegressionPrediction

# Chargement du DataFrame
df = Processing().df

# Vérification que le DataFrame n'est pas vide
if df.empty:
    raise ValueError("Le DataFrame est vide, veuillez vérifier le chargement des données.")

# Création de l'objet de prédiction pour la régression logistique
log_pred = LogisticRegressionPrediction()

# Entraînement du modèle
log_pred.train_model()

# %% [markdown]
# On peut ensuite afficher les différentes performances du modèle.

# %%
log_pred.evaluate_performance()
# Out:
# Matrice de confusion :
# ------------------------------------------------------------
# Rapport de classification
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59        14
#            1       0.00      0.00      0.00        10
#            2       0.56      0.47      0.51        19
#            3       0.69      0.87      0.77        31
#            4       0.57      0.33      0.42        12
#
#     accuracy                           0.58        86
#    macro avg       0.47      0.48      0.46        86
# weighted avg       0.53      0.58      0.55        86
#
# ------------------------------------------------------------
# Précision : 58.14%

# %% [markdown]
# Affichage des coefficients du modèle.

# %%
print(log_pred.get_model_details())
# Out:
#    Ecoscore  Taux de sel (100g)  Taux de matieres grasses (100g)  \
# a  0.297921           -2.167977                        -0.484718
# b -0.002096           -0.128612                        -0.231562
# c -0.078578            0.406365                         0.631852
# d  0.445303            0.833613                        -0.046945
# e -0.662550            1.056611                         0.131373
#
#    Taux de matieres grasses saturees (100g)  Taux de proteine (100g)  \
# a                                 -2.079540                 0.596955
# b                                 -1.455923                -0.105819
# c                                 -0.210189                -0.035545
# d                                  1.454416                 0.228794
# e                                  2.291236                -0.684386
#
#    Taux de sucre (100g)  Energie (Kcal) (100g)
# a             -1.495717               0.390748
# b             -0.642871               0.216426
# c              0.065562              -0.172597
# d              0.806772               0.186917
# e              1.266254              -0.621494

# %% [markdown]
# Ces coefficients indiquent l'effet des variables explicatives sur la probabilité d'appartenance à chaque classe, par rapport à une classe de référence.

# %% [markdown]
# **Le signe du coefficient (positif ou négatif)**
#
# Un coefficient positif pour une variable donnée (ex. Taux de sel) et une classe donnée (ex. a) signifie qu’une hausse de cette variable augmente la probabilité (ou plus précisément le log-odds) de prédire la classe en question (ici Nutriscore a).
#
# Un coefficient négatif indique au contraire qu’un accroissement de cette variable rend la classe correspondante moins probable.
#
# **L’ampleur (la valeur absolue) du coefficient**
#
# Plus la valeur (en positif ou en négatif) est grande, plus la variable exerce une influence marquée (en faveur ou en défaveur) sur la probabilité de cette classe.
#
# Par exemple, si pour la classe e, le coefficient associé au « Taux de matières grasses saturées » est très positif, cela veut dire qu’un produit riche en graisses saturées est plus susceptible d’être classé en « e » (toutes choses égales par ailleurs).
#
# ***Remarque***: Les coefficients se lisent dans l’échelle des « log-odds » (logarithme du rapport de chances). L’effet réel sur la probabilité n’est pas linéaire mais exponentiel. Cependant, l’interprétation « positif = augmente la proba, négatif = diminue la proba » reste la même.

# %% [markdown]
# ### Prédictions pour une nouvelle donnée.

# %%
# Exemple d'entraînement avec régression logistique
import pandas as pd
logistic_model = LogisticRegressionPrediction()
logistic_model.train_model()

# Prédiction sur de nouvelles données
new_data = pd.DataFrame({
    'Ecoscore': [7],
    'Taux de sel (100g)': [0.4],
    'Taux de matieres grasses (100g)': [3.2],
    'Taux de matieres grasses saturees (100g)': [1.2],
    'Taux de proteine (100g)': [6.1],
    'Taux de sucre (100g)': [12.0],
    'Energie (Kcal) (100g)': [240]
})

predictions = logistic_model.predict_nutriscore(new_data)
print(predictions)
# Out:
# d

# %% [markdown]
# Ainsi, on vérifie bien que le modèle nous permet de prédire de nouvelles observations. Dans l'exemble précédent, le modèle prédit que le produit appartient à la classe *d*.

# %% [markdown]
# ### **c) Modèle 2 : forêts aléatoires**

# %% [markdown]
# On essaie maintenant avec un modèle de *Random Forests (RF)*. On commence par créer l'instance de classe ainsi que par entraîner le modèle.

# %%
from src.services.processing import Processing
from src.services.prediction_rf import RandomForestPrediction

# Chargement du DataFrame
df = Processing().df

# Vérification que le DataFrame n'est pas vide
if df.empty:
    raise ValueError("Le DataFrame est vide, veuillez vérifier le chargement des données.")

# Création de l'objet de prédiction pour la Random Forest
rf_pred = RandomForestPrediction()

# Entraînement du modèle
rf_pred.train_model(n_estimators=200, max_depth=10)  # Personnalisez les hyperparamètres si nécessaire

# %% [markdown]
# Nous pouvons maintenant évaluer les performances du modèle :

# %%
rf_pred.evaluate_performance()
# Out:
# Matrice de confusion :
# ------------------------------------------------------------
# Rapport de classification
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        14
#            1       0.50      0.40      0.44        10
#            2       0.70      0.74      0.72        19
#            3       0.81      0.97      0.88        31
#            4       0.88      0.58      0.70        12
#
#     accuracy                           0.77        86
#    macro avg       0.75      0.69      0.71        86
# weighted avg       0.76      0.77      0.76        86
#
# ------------------------------------------------------------
# Précision : 76.74%

# %% [markdown]
# Nous nous intéressons alors à l'importance qu'à chaque coefficient dans la construction des RF :

# %%
rf_pred.get_model_details()
# Out:
# Ecoscore : 10 %
# Taux de sel (100g) : 15 %
# Taux de matieres grasses (100g) : 15 %
# Taux de matieres grasses saturees (100g) : 16 %
# Taux de proteine (100g) : 12 %
# Taux de sucre (100g) : 17 %
# Energie (Kcal) (100g) : 15 %

# %% [markdown]
# Chaque valeur dans ce vecteur correspond à l'importance d'une caractéristique dans la prédiction du modèle. Une valeur élevée indique que la caractéristique est cruciale pour la prédiction du modèle, tandis qu'une valeur faible signifie qu'elle a peu d'impact.

# %% [markdown]
# Les variables ont ici toutes un impact du même ordre de grandeur.

# %% [markdown]
# ## ***Analyse des résultats des deux modèles***

# %% [markdown]
# #### **Taux de précision et Taux d’erreur**
# ##### 1-***Random forest***
# **Accuracy** ~ 0.74 (soit **74%**) : Environ trois quarts des prédictions sont correctes, ce qui reste un bon résultat compte tenu des données à disposition.
#
# **Taux d’erreur** ~ 0.26(soit **28%**) : Cela signifie qu’un peu moins d’un quart des échantillons sont mal classés.
# ##### 2-***régression logistique***
# **Accuracy** ~ 0.57  (soit **57 %**) : À peine plus de a moitié des prédictions sont correctes, ce qui est nettement moins bien que le modèle random forest
#
# **Taux d’erreur** ~ 0.43(soit **43%**) : Le taux d'erreur est très élevée .

# %% [markdown]
# #### **Rapport de classification**
#
# Le rapport de classification indique, pour chaque classe Nutriscore, trois métriques clés :
#
# **Precision** : Parmi les prédictions de cette classe, quelle proportion est correcte ?
#
# **Recall** : Parmi tous les éléments réellement dans cette classe, quelle proportion est retrouvée comme telle ?
#
# **F1-score** : Moyenne harmonique entre la précision et le rappel, qui synthétise l’équilibre entre les deux.

# %% [markdown]
# Nous observons :
#
# Un F1-score **global** (accuracy = 0.74) pour le modèle random forest correct pour un modèle de classification sur 5 classes.
#
# Des performances légèrement plus faibles pour **b** , probablement en raison de **la taille de l’échantillon plus faible** (le nutriscore de classe b est le moins présent dans la bdd avec seulement 50 produits ) et/ou d’une plus grande similarité avec d’autres classes (par ex. c ⇔ d).
#
# De meilleures performances pour **d** et **a**, qui sont **plus nombreux** ou **plus distincts** en termes de profil nutritionnel.

# %% [markdown]
# ##### ***Pistes d’amélioration***
#
# L’erreur à 43% du modèle de régression logistique peut être réduite en :
#
# -Collectant plus de données, surtout pour les classes peu représentées (b).
#
# -Testant d’autres algorithmes plus complexes (Gradient Boosting, XGBoost, etc.) ou explorant des approches plus simples (Régularisation, PCA, features supplémentaires…).
#
# -Améliorant la qualité des features (intégration d’autres variables, meilleure gestion des valeurs manquantes, etc.).

# %% [markdown]
# #### ***Comparaison***
# En comparaison avec la régression logistique , le Random Forest :
#
# Gère mieux les spécificités de chaque classe, comme en témoigne la hausse générale de l’accuracy (passage à ~ 74 %).
#
# Améliore le rappel sur plusieurs classes (notamment “a” et “d”) ; “b” reste la moins performante, mais affiche tout de même un meilleur score qu’avant.
#
# Bénéficie probablement du fait que la Random Forest capture mieux des ***interactions non linéaires entre les variables***, et qu’elle est moins sensible à une éventuelle corrélation entre features.

# %% [markdown]
# ### ***Synthèse***
# Le Random Forest atteint une précision proche de 74 %, notablement meilleure que le modèle de régression logistique précédent. Les classes “d” et “a” sont particulièrement bien identifiées, tandis que “b” reste plus délicate à prédire — probablement en raison de sa moindre représentation ou d’un chevauchement nutritionnel avec d’autres classes. De futures optimisations, un rééquilibrage des données et l’ajout potentiel de nouvelles variables (ou un ajustement des hyperparamètres) pourraient encore améliorer ces performances.

# %% [markdown]
# ## **5- Conclusion**
#
#
# En s’appuyant sur Open Food Facts, ce projet entend participer à une meilleure compréhension de notre alimentation. La richesse des données disponibles, combinée à l’analyse statistique, à la visualisation, et à la modélisation prédictive, permettra de mettre en évidence les facteurs qui influencent la qualité nutritionnelle des produits. Bien que la problématique initiale reste volontairement large (« découvrir davantage notre alimentation »), le projet s’affine progressivement vers la prédiction du Nutriscore, démontrant ainsi l’intérêt pratique de l’exploitation de données ouvertes dans le domaine agroalimentaire.
